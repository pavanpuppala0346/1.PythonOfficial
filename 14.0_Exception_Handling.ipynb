# %% [markdown]
# ## In any programming language there are 2 types of errors are possible.
# - 1. Syntax Errors
# - 2. Runtime Errors(logical errors)

# %% [markdown]
# #### 1. Syntax Errors : The errors which occurs because of invalid syntax are called syntax errors.

# %%
x=10
if x==10
print("Hello")
# Out:
#   File "<ipython-input-1-709172b1258f>", line 2
#     if x==10
#             ^
# SyntaxError: invalid syntax

# %%
print "Hello"
# Out:
#   File "<ipython-input-2-dabf489e9f92>", line 1
#     print "Hello"
#                 ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello")?

# %% [markdown]
# #### Note: Programmer is responsible to correct these syntax errors. Once all syntax errors are corrected then only program execution will be started.

# %% [markdown]
# #### 2. Runtime Errors(logical errors): Also known as exceptions. While executing the program if something goes wrong because of end user input or programming logic or memory problems etc then we will get Runtime Errors.

# %%
#print(10/0) #ZeroDivisionError: division by zero

# %%
#print(10/"ten") #TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
#x=int(input("Enter number:"))   #ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# #### Note: Exception Handling concept applicable for Runtime Errors but not for syntax errors

# %% [markdown]
# ## Exception: An unwanted and unexpected event that disturbs normal flow of program is called exception.
# - Ex:ZeroDivisionError, TypeError, ValueError, FileNotFoundError, EOFError(End Of File Error).

# %% [markdown]
# - It is highly recommended to handle exceptions. The main objective of exception handling is Graceful Termination of the program(i.e we should not block our resources and we should not miss anything)
# - Exception handling does not mean repairing exception. We have to define alternative way to continue rest of the program normally.
# - For example our programming requirement is reading data from remote file locating at London. At runtime if london file is not available then the program should not be terminated abnormally. We have to provide local file to continue rest of the program normally. This way of defining alternative is nothing but exception handling.

# %% [markdown]
# #### try:
#         read data from remote file locating at london
# #### except FileNotFoundError:
#         use local file and continue rest of the program normally

# %% [markdown]
# ## Default Exception Handing in Python:

# %% [markdown]
# - Every exception in Python is an object. For every exception type the corresponding classes are available.
# - Whevever an exception occurs PVM will create the corresponding exception object and will check for handling code. If handling code is not available then Python interpreter terminates the program abnormally and prints corresponding exception information to the console.
# - The rest of the program won't be executed.

# %%
print("hello")
print(10/0)
print("pawan")
# Out:
# hello
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-318da4e13234> in <module>
#       1 print("hello")
# ----> 2 print(10/0)
#       3 print("pawan")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Python's Exception Hierarchy

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/python/exception1.png")

# %% [markdown]
# - Every Exception in Python is a class.
# - All exception classes are child classes of BaseException.i.e every exception class extends BaseException either directly or indirectly. Hence BaseException acts as root for Python Exception Hierarchy.
# - Most of the times being a programmer we have to concentrate Exception and its child classes.

# %% [markdown]
# ## Customized Exception Handling by using try-except:
# - It is highly recommended to handle exceptions.
# - The code which may raise exception is called risky code and we have to take risky code inside try block.
# - The corresponding handling code we have to take inside except block.

# %% [markdown]
# #### try:
#         Risky Code
# #### except XXX:
#         Handling code/Alternative Code

# %% [markdown]
# #### without try-except:

# %%
print("hello")
print(10/0)
print("pawan") #ZeroDivisionError: division by zero # Abnormal termination/Non-Graceful Termination
# Out:
# hello
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-318da4e13234> in <module>()
#       1 print("hello")
# ----> 2 print(10/0)
#       3 print("pawan")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### with try-except:

# %%
print("hello")
try:
    print(10/0)
except ZeroDivisionError:
    print("10 is not divisble by 0")
print("pawan")             # Normal termination/Graceful Termination
# Out:
# hello
# 10 is not divisble by 0
# pawan

# %% [markdown]
# ## Control Flow in try-except:

# %% [markdown]
# #### try:
#         stmt-1
#         stmt-2
#         stmt-3
# #### except XXX:
#         stmt-4
# stmt-5

# %% [markdown]
# - case-1: If there is no exception ---> 1,2,3,5 and Normal Termination
# - case-2: If an exception raised at stmt-2 and corresponding except block matched ---> 1,4,5 Normal Termination
# - case-3: If an exception raised at stmt-2 and corresponding except block not matched ---> 1, Abnormal Termination
# - case-4: If an exception raised at stmt-4 or at stmt-5 then it is always abnormal termination.

# %% [markdown]
# ## Conclusions:
# - 1. within the try block if anywhere exception raised then rest of the try block wont be executed eventhough we handled that exception. Hence we have to take only risky code inside try block and length of the try block should be as less as possible.
# - 2. In addition to try block,there may be a chance of raising exceptions inside except and finally blocks also.
# - 3. If any statement which is not part of try block raises an exception then it is always "abnormal termination".

# %% [markdown]
# ## How to print exception information:

# %%
try:
    print(10/0)
except ZeroDivisionError as msg:
    print("exception raised and its description is:",msg)
# Out:
# exception raised and its description is: division by zero

# %% [markdown]
# ## try with multiple except blocks:
# - The way of handling exception is varied from exception to exception.Hence for every exception type a seperate except block we have to provide. i.e try with multiple except blocks is possible and recommended to use.
# - If try with multiple except blocks available then based on raised exception the corresponding except block will be executed.

# %%
try:
    x=int(input("Enter First number:"))
    y=int(input("Enter Second number:"))
    print(x/y)
except ZeroDivisionError:
    print("division by zero not possible")
except ValueError:
    print("please provide the int value")
# Out:
# Enter First number:10
# Enter Second number:zero
# please provide the int value

# %% [markdown]
# - If try with multiple except blocks available then the order of these except blocks is important .Python interpreter will always consider from top to bottom until matched except block identified.

# %%
try:
    x=int(input("Enter First number:"))
    y=int(input("Enter Second number:"))
    print(x/y)
except ArithmeticError:
    print("1.Arthematic Error")
except ZeroDivisionError:
    print("2.division by zero not possible")
# Out:
# Enter First number:10
# Enter Second number:0
# 1.Arthematic Error

# %% [markdown]
# ## Single except block that can handle multiple exceptions:
# - We can write a single except block that can handle multiple different types of exceptions.
#     - except (Exception1,Exception2,exception3,..): or
#     - except (Exception1,Exception2,exception3,..) as msg :
# - Parenthesis are mandatory and this group of exceptions internally considered as tuple.

# %%
try:
    x=int(input("Enter First number:"))
    y=int(input("Enter Second number:"))
    print(x/y)
except (ZeroDivisionError,ValueError) as msg:
    print("please provide valid numbers:",msg)
# Out:
# Enter First number:10
# Enter Second number:ten
# please provide valid numbers: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ## Default except block:
# - We can use default except block to handle any type of exceptions.
# - In default except block generally we can print normal error messages.
# - Syntax: except:
#               statements

# %%
try:
    x=int(input("Enter First number:"))
    y=int(input("Enter Second number:"))
    print(x/y)
except ZeroDivisionError:
    print("division by zero not possible")
except:
    print("please provide the valid int value")
# Out:
# Enter First number:10
# Enter Second number:0
# division by zero not possible

# %% [markdown]
# #### Note: If try with multiple except blocks available then default except block should be last,otherwise we will get SyntaxError.

# %%
try:
    print(10/0)
except:
    print("Default Except")
except ZeroDivisionError:
    print("ZeroDivisionError")
# Out:
#   File "<ipython-input-4-ef2c08753a39>", line 2
#     print(10/0)
#             ^
# SyntaxError: default 'except:' must be last

# %% [markdown]
# ### Note:
# The following are various possible combinations of except blocks
# 1. except ZeroDivisionError:
# 2. except ZeroDivisionError as msg:
# 3. except (ZeroDivisionError,ValueError) :
# 4. except (ZeroDivisionError,ValueError) as msg:
# 5. except :

# %% [markdown]
# ## finally block:
# - It is not recommended to maintain clean up code(Resource Deallocating Code or Resource Releasing code) inside try block because there is no guarentee for the execution of every statement inside try block always.
# - It is not recommended to maintain clean up code inside except block, because if there is no exception then except block won't be executed.
# - Hence we required some place to maintain clean up code which should be executed always irrespective of whether exception raised or not raised and whether exception handled or not handled. Such type of best place is nothing but finally block.
# - Hence the main purpose of finally block is to maintain clean up code.
# - The speciality of finally block is it will be executed always whether exception raised or not raised and whether exception handled or not handled.

# %% [markdown]
# #### try:
#          Risky Code
# #### except:
#          Handling Code
# #### finally:
#          Cleanup code

# %% [markdown]
# #### Case-1: If there is no exception

# %%
try:
    print("try")
except:
    print("except")
finally:
    print("finally")
# Out:
# try
# finally

# %% [markdown]
# #### Case-2: If there is an exception raised but handled:

# %%
try:
    print("try")
    print(10/0)
except ZeroDivisionError:
    print("except")
finally:
    print("finally")
# Out:
# try
# except
# finally

# %% [markdown]
# #### Case-3: If there is an exception raised but not handled:

# %%
try:
    print("try")
    print(10/0)
except NameError:
    print("except")
finally:
    print("finally")
# Out:
# try
# finally
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-0010f7c00949> in <module>()
#       1 try:
#       2     print("try")
# ----> 3     print(10/0)
#       4 except NameError:
#       5     print("except")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #### Note:
# - There is only one situation where finally block won't be executed ie whenever we are using os._exit(0) function.
# - Whenever we are using os._exit(0) function then Python Virtual Machine itself will be shutdown.In this particular case finally won't be executed.

# %%
import os

try:
    print("try")
   # os._exit(0)
    print(10/0)
except ZeroDivisionError:
    print("except")
finally:
    print("finally")
# Out:
# try
# except
# finally

# %% [markdown]
# #### Note: os._exit(0) where 0 represents status code and it indicates normal termination There are multiple status codes are possible.

# %% [markdown]
# ## Control flow in try-except-finally:

# %% [markdown]
# #### try:
#          stmt-1
#          stmt-2
#          stmt-3
# #### except:
#          stmt-4
# #### finally:
#          stmt-5
# stmt6

# %% [markdown]
# - Case-1: If there is no exception ---> 1,2,3,5,6 Normal Termination
# - Case-2: If an exception raised at stmt2 and the corresponding except block matched ---> 1,4,5,6 Normal Termination
# - Case-3: If an exception raised at stmt2 but the corresponding except block not matched ---> 1,5 Abnormal Termination
# - Case-4: If an exception raised at stmt4 then it is always abnormal termination but before that finally block will be executed.
# - Case-5: If an exception raised at stmt-5 or at stmt-6 then it is always abnormal termination

# %% [markdown]
# ## Nested try-except-finally blocks:
# - We can take try-except-finally blocks inside try or except or finally blocks.i.e nesting of try-except-finally is possible.

# %% [markdown]
# #### try:                     risky code
#         try:        too much risky code
#         except:
#         finally:
# #### except:
#         try:
#         except:
#         finally:
# #### finally:
#         try:
#         except:
#         finally:

# %% [markdown]
# - General Risky code we have to take inside outer try block and too much risky code we have to take inside inner try block. Inside Inner try block if an exception raised then inner except block is responsible to handle. If it is unable to handle then outer except block is responsible to handle.

# %%
try:
    print("outer try block")
    try:
        print("Inner try block")
        print(10/0)
    except ZeroDivisionError:
        print("Inner except block")
    finally:
        print("Inner finally block")
except:
    print("outer except block")
finally:
    print("outer finally block")
# Out:
# outer try block
# Inner try block
# Inner except block
# Inner finally block
# outer finally block

# %% [markdown]
# ## Control flow in nested try-except-finally:

# %%
try:
    stmt-1
    stmt-2
    stmt-3 
    try:
        stmt-4 
        stmt-5 
        stmt-6 
    except X: 
        stmt-7
    finally: 
        stmt-8 
    stmt-9 
except Y: 
    stmt-10
finally:
    stmt-11
stmt-12

# %% [markdown]
# - case-1: If there is no exception 1,2,3,4,5,6,8,9,11,12 NT
# - case-2: If an exception raised at stmt-2 and the corresponding except block matched 1,10,11,12 NT
# - case-3: If an exceptiion raised at stmt-2 and the corresponding except block not matched 1,11 AT(only finally block get execute)
# - case-4: If an exception raised at stmt-5 and inner except block matched 1,2,3,4,7,8,9,11,12 NT
# - case-5: If an exception raised at stmt-5 and inner except block not matched but outer except block matched
#           1,2,3,4,8,10,11,12 NT
# - case-6:If an exception raised at stmt-5 and both inner and outer except blocks are not matched
#          1,2,3,4,8,11 AT
# - case-7: If an exception raised at stmt-7 and corresponding except block matched 1,2,3,_ _ _,8,10,11,12 NT
# - case-8: If an exception raised at stmt-7 and corresponding except block not matched 1,2,3,_ _ _,8,11 AT
# - case-9: If an exception raised at stmt-8 and corresponding except block matched 1,2,3,_ _ _ _,10,11,12 NT
# - case-10: If an exception raised at stmt-8 and corresponding except block not matched 1,2,3,_ _ _ _,11 AT
# - case-11: If an exception raised at stmt-9 and corresponding except block matched 1,2,3,_ _ _ _ ,8,10,11,12 NT
# - case-12: If an exception raised at stmt-9 and corresponding except block not matched 1,2,3,.,.,.,.,8,11 AT
# - case-13: If an exception raised at stmt-10 then it is always AT but before AT finally block(stmt-11) will be executed.
# - case-14: If an exception raised at stmt-11 or stmt-12 then it is always AT.

# %% [markdown]
# #### Note: If the control entered into try block then compulsary finally block will be executed. If the control not entered into try block then finally block won't be executed.

# %% [markdown]
# ## else block with try-except-finally:
# - We can use else block with try-except-finally blocks.
# - else block will be executed if and only if there are no exceptions inside try block.

# %% [markdown]
# #### try:
#     Risky Code
# #### except:
#     will be executed if exception inside try
# #### else:
#     will be executed if there is no exception inside try
# #### finally:
#     will be executed whether exception raised or not raised and handled or not handled

# %%
try:
    print("try block")
    #print(10/0)
except:
    print("except block")
else:
    print("else block")
finally:
    print("finally block")
# Out:
# try block
# else block
# finally block

# %% [markdown]
# ## Various possible combinations of try-except-else-finally:
# 1. Whenever we are writing try block, compulsory we should write except or finally block.i.e without except or finally block we cannot write try block.
# 2. Wheneever we are writing except block, compulsory we should write try block. i.e except without try is always invalid.
# 3. Whenever we are writing finally block, compulsory we should write try block. i.e finally without try is always invalid.
# 4. We can write multiple except blocks for the same try,but we cannot write multiple finally blocks for the same try
# 5. Whenever we are writing else block compulsory except block should be there. i.e without except we cannot write else block.
# 6. In try-except-else-finally order is important.
# 7. We can define try-except-else-finally inside try,except,else and finally blocks. i.e nesting of try-except-else-finally is always possible.

# %% [markdown]
# - try:
# - except:

# %% [markdown]
# - try:
# - finally:

# %% [markdown]
# - try
# - except
# - except
# - except
# - finally

# %% [markdown]
# - try
# - except
# - else
# - finally

# %% [markdown]
# - try
#     try
#     except
#     else
#     finally
# - except
#     try
#     except
#     else
#     finally
# - else
#     try
#     except
#     else
#     finally
# - finally
#         try
#     except
#     else
#     finally

# %%
try: 
    print("try")
# Out:
#   File "<ipython-input-17-f5da66bd8bee>", line 2
#     print("try")
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
except: 
    print("Hello")
# Out:
#   File "<ipython-input-18-9ef5e871d6ca>", line 1
#     except:
#          ^
# SyntaxError: invalid syntax

# %%
else: 
    print("Hello")
# Out:
#   File "<ipython-input-19-c88f8247cbb3>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
finally:
    print("Hello")
# Out:
#   File "<ipython-input-21-4839f91c0ae7>", line 1
#     finally:
#           ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
except:
    print("exception")
# Out:
# try

# %%
try: 
    print("try") 
finally:
    print("finally")
# Out:
# try
# finally

# %%
try: 
    print("try")
    #print(10/0)
except:
    print("except") 
else:
    print("else")
# Out:
# try
# except

# %%
try:
    print("try")
else: 
    print("else")
# Out:
#   File "<ipython-input-10-5f0008d36e55>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try:
    print("try")
else:
    print("else")
finally:
    print("finally")
# Out:
#   File "<ipython-input-11-a8e1913a175b>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try:
    print("try") 
except XXX: 
    print("except-1")
except YYY: 
    print("except-2")
# Out:
# try

# %%
try:
    print("try") 
except:
    print("except-1") 
else: 
    print("else") 
else:
    print("else")
# Out:
#   File "<ipython-input-13-f781a797302e>", line 7
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try:
    print("try")
except:
    print("except-1") 
finally:
    print("finally") 
finally:
    print("finally")
# Out:
#   File "<ipython-input-14-9ad5971b896b>", line 7
#     finally:
#           ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try")
print("Hello") 
except:
    print("except")
# Out:
#   File "<ipython-input-16-09a650dcb648>", line 3
#     print("Hello")
#         ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try")
except:
    print("except")
print("Hello") 
except:
    print("except")
# Out:
#   File "<ipython-input-16-a2073c675957>", line 6
#     except:
#          ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
except:
    print("except") 
print("Hello") 
except: 
    print("except")
# Out:
#   File "<ipython-input-18-d7e3805e0b4f>", line 6
#     except:
#          ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
except: 
    print("except")
print("Hello")
finally:
    print("finally")
# Out:
#   File "<ipython-input-19-a261585ca406>", line 6
#     finally:
#           ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
except: 
    print("except")
print("Hello")
else:
    print("else")
# Out:
#   File "<ipython-input-20-71842948dc16>", line 6
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
except: 
    print("except")
try: 
    print("try") 
except: 
    print("except")
# Out:
# try
# try

# %%
try: 
    print("try") 
except: 
    print("except")
try: 
    print("try") 
finally: 
    print("finally")
# Out:
# try
# try
# finally

# %%
try: 
    print("try") 
except: 
    print("except")
if 10>20: 
    print("if") 
else:
    print("else")
# Out:
# try
# else

# %%
try: 
    print("try")
    try: 
        print("inner try") 
    except: 
        print("inner except block") 
    finally: 
        print("inner finally block")
except: 
    print("except")
# Out:
# try
# inner try
# inner finally block

# %%
try: 
    print("try")
except: 
    print("except")
    try: 
        print("inner try") 
    except: 
        print("inner except block") 
    finally: 
        print("inner finally block")
# Out:
# try

# %%
try: 
    print("try")
except: 
    print("except")
finally:
    print("finally")
    try: 
        print("inner try") 
    except: 
        print("inner except block") 
    finally: 
        print("inner finally block")
# Out:
# try
# finally
# inner try
# inner finally block

# %%
try: 
    print("try") 
except:
    print("except") 
try:
    print("try")
else: 
    print("else")
# Out:
#   File "<ipython-input-27-ff3d87ce9a24>", line 7
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try") 
    try:
        print("inner try")
except:
    print("except")
# Out:
#   File "<ipython-input-28-23934265b059>", line 5
#     except:
#            ^
# IndentationError: unexpected unindent

# %%
try: 
    print("try") 
else:
    print("else") 
except: 
    print("except") 
finally:
    print("finally")
# Out:
#   File "<ipython-input-29-479464da6e90>", line 3
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
try: 
    print("try")  
except: 
    print("except") 
else:
    print("else")
finally:
    print("finally")
# Out:
# try
# else
# finally

# %% [markdown]
# ## Types of Exceptions: In python there are two types of exceptions are possible
# - pre defined Exceptions
# - user defined Exceptions

# %% [markdown]
# #### 1. Predefined Exceptions
# - Also known as in-built exceptions
# - The exceptions which are raised automatically by PVM whenver a particular event occurs, are called pre defined exceptions.

# %%
#print(10/0)  #ZeroDivisionError: division by zero
#x=int("ten")  #ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# #### 2. User Defined Exceptions:
# - Also known as Customized Exceptions or Programatic Exceptions
# - Some time we have to define and raise exceptions explicitly to indicate that something goes wrong ,such type of exceptions are called User Defined Exceptions or Customized Exceptions
# - Programmer is responsible to define these exceptions and Python not having any idea about these. Hence we have to raise explicitly based on our requirement by using "raise" keyword.

# %% [markdown]
# #### Eg:
# - InSufficientFundsException
# - InvalidInputException

# %% [markdown]
# ## How to Define and Raise Customized Exceptions:
# - Every exception in Python is a class that extends Exception class either directly or indirectly
# - Syntax:
#           class classname(predefined exception class name):
#               def __init__(self,arg):
#                   self.msg=arg

# %% [markdown]
# - TooYoungException is our class name which is the child class of Exception
# - We can raise exception by using raise keyword as follows
#     raise TooYoungException("message")

# %%
class tooOldException(Exception):
    def __init__(self,arg):
        self.msg=arg
        
class tooYoungException(Exception):
    def __init__(self,arg):
        self.msg=arg
        
age=int(input("Enter Age:"))
if age>60:
    raise tooYoungException("Plz wait some more time you will get best match soon!!!")
elif age<18:
    raise tooOldException("Your age already crossed marriage age...no chance of getting marriage")
else:
    print("You will get match details soon by email!!!")
# Out:
# Enter Age:99
# ---------------------------------------------------------------------------
# tooYoungException                         Traceback (most recent call last)
# <ipython-input-8-3e4315189926> in <module>
#       9 age=int(input("Enter Age:"))
#      10 if age>60:
# ---> 11     raise tooYoungException("Plz wait some more time you will get best match soon!!!")
#      12 elif age<18:
#      13     raise tooOldException("Your age already crossed marriage age...no chance of getting marriage")
#
# tooYoungException: Plz wait some more time you will get best match soon!!!

# %% [markdown]
# #### Note: raise keyword is best suitable for customized exceptions but not for pre defined exceptions

# %%
every exception in python is a class

# %%
x=10
print(x)
# Out:
# 10

# %%
x=10

def prod(n1,n2):
    return n1*n2
try:
    print(x)  #Name error
    r=prod(10) #type error
except:
    print("some exception in your code")
# Out:
# 10
# some exception in your code

# %%
x=10

def prod(n1,n2):
    return n1*n2
try:
    print(x)  #Name error
    r=prod(10) #type error
    
except NameError:
    print("variable not found")
except TypeError:
    print("Check Argument list")
except:            # generic exception handling routine
    print("some exception in your code")
# Out:
# 10
# Check Argument list

# %%
x=10

def prod(n1,n2):
    return n1*n2
try:
    print(y)  #Name error
    r=prod(10) #type error
    
except NameError:
    print("variable not found")
except TypeError:
    print("Check Argument list")
except:            # generic exception handling routine
    print("some exception in your code")
# Out:
# variable not found

# %%
x=10

def prod(n1,n2):
    return n1*n2
try:
    print(x)  #Name error
    r=prod(10,2) #type error
    10/0
    
except NameError:
    print("variable not found")
except TypeError:
    print("Check Argument list")
except:            # generic exception handling routine
    print("some exception in your code")
finally:
    print("execute always...")
# Out:
# 10
# some exception in your code
# execute always...

# %%
x=10

def prod(n1,n2):
    return n1*n2
try:
    print(x)  #Name error
    r=prod(10,2) #type error
    z=10/2
    
except NameError:
    print("variable not found")
except TypeError:
    print("Check Argument list")
except:            # generic exception handling routine
    print("some exception in your code")
else:
    print("it executes when try will not generates any exception at run time")
finally:
    print("execute always...")
# Out:
# 10
# it executes when try will not generates any exception at run time
# execute always...

# %% [markdown]
# #file handling

# %% [markdown]
# #### open()
# #### read()
# #### write()
# #### close()

# %% [markdown]
# open(file name, mode)
# open("a.txt",w)--> new file

# %% [markdown]
# ## DB connections

# %%
#load drivers
import pypyodbc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-4cb2f0f17733> in <module>()
#       1 #load drivers
# ----> 2 import pypyodbc
#
# ModuleNotFoundError: No module named 'pypyodbc'

# %%
#connect to DB

# %%
#connect to a table

# %%
#CURD

# %%
#Execute--> Recordset --> variable

# %%
#Loop --> record by record

# %%
#Close Connection
