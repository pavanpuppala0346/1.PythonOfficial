# %% [markdown]
# ## Types of variables: Inside Python class 3 types of variables are allowed.
# - 1. Instance Variables (Object Level Variables)
# - 2. Static Variables (Class Level Variables)
# - 3. Local variables (Method Level Variables)

# %% [markdown]
# ## 1. Instance Variables:
# - If the value of a variable is varied from object to object, then such type of variables are called instance variables.
# - For every object a separate copy of instance variables will be created.
# - Ex: for every 500 students has a 500 names and 500 roll no.

# %% [markdown]
# #### Where we can declare Instance variables:
# - 1. Inside Constructor by using self variable
# - 2. Inside Instance Method by using self variable
# - 3. Outside of the class by using object reference variable

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/var1.png")

# %% [markdown]
# #### Accesing
# - We can access instance variables with in the class by using self variable and outside of the class by using object reference.

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/var2.png")

# %%
class Employee:
    def __init__(self):
        self.name="swamy"
        self.age=25
        
    def talk(self):
        print(self.name)     # within the class by using self
        print(self.age)
        
e=Employee()
e.talk()
# Out:
# swamy
# 25

# %%
print(e.name)              # outside the class by using obj ref.
print(e.age)
# Out:
# swamy
# 25

# %% [markdown]
# #### delete instance variable

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/var3.png")

# %%
class Employee:
    def __init__(self):
        self.name="swamy"
        self.age=25
        self.qual="btech"
        self.place="bvrm"
        
    def talk(self):
        del self.name     # within the class by using del self.variablename

# %%
e=Employee()
e.__dict__
# Out:
# {'name': 'swamy', 'age': 25, 'qual': 'btech', 'place': 'bvrm'}

# %%
e.talk()
e.__dict__
# Out:
# {'age': 25, 'qual': 'btech', 'place': 'bvrm'}

# %%
del e.place              # Outside of the class del objref.variablename
e.__dict__
# Out:
# {'age': 25, 'qual': 'btech'}

# %% [markdown]
# #### ***NOTE: for declaring, accessing, deleting of instance variable
# - inside of the class we are using 'self' variable
# - outside of the class we are using 'obj ref' variable

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/oop3.png")

# %% [markdown]
# #### ***NOTE: Instanace variables which are deleted from one object will not be deleted for another objects

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/var4.png")

# %% [markdown]
# #### ***NOTE: if changes happen in one object should not effect to another object becoz for every obj a separate copy of instance varibale are available

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/var5.png")

# %% [markdown]
# ## 2. Static Variables
# - The value of variable which is not varied from object to object.
# - For total class only one copy of static variable will be created and shared by all objects of that class.
# - We can access static variables either by class name or by object reference. But recommended to use class name.

# %%
import IPython.display as d
d.Image("E:/code/1.pythonofficial/img/oop4.png")

# %% [markdown]
# #### Declaring with classname good practice
# - 1. In general we can declare within the class directly but from out side of any method
# - 2. Inside constructor by using class name
# - 3. Inside instance method by using class name
# - 4. Inside classmethod by using either class name or cls variable
# - 5. Inside static method by using class name

# %%
from IPython.display import Image
Image("E:/code/1.pythonofficial/img/svar1.png")

# %%
class Test:
    a=10               #directly inside of class & outside of method
    def __init__(self):
        Test.b=20      #using classname
        
    def m1(self):
        Test.c=30      #using classname
        
    @classmethod
    def m2(cls):
        cls.d1=40      #using cls variable or classname
        Test.d2=444
    
    @staticmethod
    def m3():
        Test.e=50      #using classname

# %%
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None}

# %%
t=Test()
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20}

# %%
t.m1()
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20, 'c': 30}

# %%
Test.m2()
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20, 'c': 30, 'd1': 40, 'd2': 444}

# %%
Test.m3()
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20, 'c': 30, 'd1': 40, 'd2': 444, 'e': 50}

# %%
Test.f=60
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38C89D8>, 'm1': <function Test.m1 at 0x00000187A38C8A60>, 'm2': <classmethod object at 0x00000187A38CD3C8>, 'm3': <staticmethod object at 0x00000187A38CD438>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20, 'c': 30, 'd1': 40, 'd2': 444, 'e': 50, 'f': 60}

# %% [markdown]
# #### Accessing
# - 1. inside constructor: by using either self or classname
# - 2. inside instance method: by using either self or classname
# - 3. inside class method: by using either cls variable or classname
# - 4. inside static method: by using classname
# - 5. From outside of class: by using either object reference or classnmae

# %%
class Test:
    a = 10
    def __init__(self):
        print("constructor:",self.a)
        print("constructor:",Test.a)
        
    def m1(self):
        print("Instance method:",self.a)
        print("Instance method:",Test.a)
        
    @classmethod
    def m2(cls):
        print("Class method:",cls.a)
        print("Class method:",Test.a)
        
    @staticmethod
    def m3():
        print("Static method:",Test.a)

# %%
t = Test()
t.m1()
t.m2()
t.m3()
# Out:
# constructor: 10
# constructor: 10
# Instance method: 10
# Instance method: 10
# Class method: 10
# Class method: 10
# Static method: 10

# %% [markdown]
# ####  NOTE: Where we can modify the value of static variable:
# - Anywhere either with in the class or outside of class we can modify by using classname. But inside class method, by using cls variable.

# %%
class Test:
    a=777
    
    @classmethod
    def m1(cls):
        cls.a=888
        
    @staticmethod
    def m2():
        Test.a=999
        
print(Test.a)
Test.m1()
print(Test.a)
Test.m2()
print(Test.a)
# Out:
# 777
# 888
# 999

# %% [markdown]
# #### NOTE:
# - declaring,modifying and deleting of class or static variable by using "classname or cls variable"
# -  accessing we use self,classname,cls,obj ref.

# %% [markdown]
# #### ***NOTE: If we change the value of static variable by using either self or object reference variable:
# - If we change the value of static variable by using either self or object reference variable, then the value of static variable won't be changed,just a new instance variable with that name will be added to that particular object.

# %%
class Test:
    a = 10
    def m1(self):
        self.a = 888
        
t1 = Test()
t1.m1()

print(Test.a)
print(t1.a)
# Out:
# 10
# 888

# %%
class Test:
    x=10
    def __init__(self):
        self.y=20
        
t1=Test()
t2=Test()

print('t1:',t1.x,t1.y)
print('t2:',t2.x,t2.y)
# if you want to modify the static varibale we have to use classname 
# other wise if we use self variable it will create an instance variable

t1.x=888
t1.y=999 

print('t1:',t1.x,t1.y)
print('t2:',t2.x,t2.y)
# Out:
# t1: 10 20
# t2: 10 20
# t1: 888 999
# t2: 10 20

# %%
class Test:
    a=10
    def __init__(self):
        self.b=20
        
t1=Test()
t2=Test()

Test.a=888
t1.b=999
print(t1.a,t1.b)
print(t2.a,t2.b)
# Out:
# 888 999
# 888 20

# %%
class Test:
    a=10
    def __init__(self):
        self.b=20
    def m1(self):
        self.a=888
        self.b=999
t1=Test()
t2=Test()
t1.m1()
print(t1.a,t1.b)
print(t2.a,t2.b)
# Out:
# 888 999
# 10 20

# %%
class Test:
    a=10
    def __init__(self):
        self.b=20
    @classmethod
    def m1(cls):
        cls.a=888
        cls.b=999
t1=Test()
t2=Test()
t1.m1()
print(t1.a,t1.b)
print(t2.a,t2.b)
print(Test.a,Test.b)
# Out:
# 888 20
# 888 20
# 888 999

# %% [markdown]
# ## deleting
# - we can delete static variable from anywhere "del classname.variblename"
# - but inside of the class method "del cls.variablename"

# %%
class Test:
    a=10
    @classmethod
    def m1(cls):
        del cls.a
Test.m1()
print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'm1': <classmethod object at 0x00000187A38CCB70>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None}

# %%
class Test:
    a=10
    def __init__(self):
        Test.b=20
        del Test.a
        
    def m1(self):
        Test.c=30
        del Test.b
        
    @classmethod
    def m2(cls):
        cls.d=40
        del Test.c
    
    @staticmethod
    def m3():
        Test.e=50
        del Test.d

# %%
print(Test.__dict__)
t=Test()
print(Test.__dict__)
t.m1()
print(Test.__dict__)
Test.m2()
print(Test.__dict__)
Test.m3()
print(Test.__dict__)
Test.f=60
print(Test.__dict__)
#del Test.e
#print(Test.__dict__)
# Out:
# {'__module__': '__main__', 'a': 10, '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None}
# {'__module__': '__main__', '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'b': 20}
# {'__module__': '__main__', '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'c': 30}
# {'__module__': '__main__', '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'd': 40}
# {'__module__': '__main__', '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'e': 50}
# {'__module__': '__main__', '__init__': <function Test.__init__ at 0x00000187A38B5D08>, 'm1': <function Test.m1 at 0x00000187A38B5AE8>, 'm2': <classmethod object at 0x00000187A38D86D8>, 'm3': <staticmethod object at 0x00000187A38D8630>, '__dict__': <attribute '__dict__' of 'Test' objects>, '__weakref__': <attribute '__weakref__' of 'Test' objects>, '__doc__': None, 'e': 50, 'f': 60}

# %% [markdown]
# #### Note:
# - By using object reference variable/self we can read static variables, but we cannot modify or delete.
# - If we are trying to modify, then a new instance variable will be added to that particular object. t1.a = 70
# - If we are trying to delete then we will get error.

# %%
class Test:
    a=10
    
t1=Test()
del t1.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-9e83a0fa6557> in <module>()
#       3
#       4 t1=Test()
# ----> 5 del t1.a
#
# AttributeError: a

# %% [markdown]
# #### We can modify or delete static variables only by using classname or cls variable.

# %%
import sys

class Customer:
    """Customer class with bank operations"""
    bankname="Bank of Bhimavaram"
    
    def __init__(self,name,balance=0.0):
        self.name=name
        self.balance=balance
        
    def deposit(self,amt):
        self.balance=self.balance+amt
        print("Balance after Deposit",self.balance)
        
    def withdraw(self,amt):
        if amt>self.balance:
            print("Insufficient Funds")
            sys.exit()
        self.balance=self.balance-amt
        print("Balance after Withdrawn",self.balance)
    
print("Welcome to ",Customer.bankname)

name=input("Enter name of the customer:")
c=Customer(name)

while True:
    print("d-Deposit \nw-Withdrawn \ne=Exit")
    option=input("Choose your option:")
    if option=="d" or option=="D":
        amt = float(input("Enter Amount:"))
        c.deposit(amt)
        
    elif option=="w" or option=="W":
        amt = float(input("Enter Amount:"))
        c.withdraw(amt)
        
    elif option=="e" or option=="E":
        print("Thanks for Banking..")
        sys.exit()
    else:
        print("Invalid option.please choose valid option..")
# Out:
# Welcome to  Bank of Bhimavaram
# Enter name of the customer:pawan
# d-Deposit
# w-Withdrawn
# e=Exit
# Choose your option:d
# Enter Amount:1200
# Balance after Deposit 1200.0
# d-Deposit
# w-Withdrawn
# e=Exit
# Choose your option:w
# Enter Amount:900
# Balance after Withdrawn 300.0
# d-Deposit
# w-Withdrawn
# e=Exit
# Choose your option:e
# Thanks for Banking..
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\LENOVO\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Instance Variable vs Static Variable:
# - Note: In the case of instance variables for every object a seperate copy will be created,but in the case of static variables for total class only one copy will be created and shared by every object of that class.

# %%
class Test:
    x=10
    def __init__(self):
        self.y=20

t1=Test()
t2=Test()

print('t1:',t1.x,t1.y)
print('t2:',t2.x,t2.y)

Test.x=888
t1.y=999

print('t1:',t1.x,t1.y)
print('t2:',t2.x,t2.y)
# Out:
# t1: 10 20
# t2: 10 20
# t1: 888 999
# t2: 888 20

# %% [markdown]
# ## 3. local variable
# - Sometimes to meet temporary requirements of programmer,we can declare variables inside a method directly,such type of variables are called local variable or temporary variables.
# - Local variables will be created at the time of method execution and destroyed once method completes.
# - Local variables of a method cannot be accessed from outside of method.

# %%
class Test:
    def m1():
        i=0
        while i<10:
            print("Hello",i)
            i=i+1
            
Test.m1()
# Out:
# Hello 0
# Hello 1
# Hello 2
# Hello 3
# Hello 4
# Hello 5
# Hello 6
# Hello 7
# Hello 8
# Hello 9

# %%
class Test1:
    def m1(self):
        a=1000
        print(a)
    
    def m2(self):
        b=2000
        print(b)
t=Test1()
t.m1()
t.m2()
# Out:
# 1000
# 2000

# %%
class Test2:
    def m1():
        a=100
        print(a)
        
    def m2():
        b=200
        #print(a)   #NameError: name 'a' is not defined
        print(b)
        
Test2.m1()
Test2.m2()
# Out:
# 100
# 200

# %% [markdown]
# ## 3 types of methods
# - Instance methods(Object)--> no decorator
# - class methods           --> @classmethod(mandatory)
# - static methods          --> @staticmethod(optional)

# %% [markdown]
# #### Instance method
# - Inside method implementation if we are using instance variables then such type of methods are called instance methods. Inside instance method declaration,we have to pass self variable.
# def m1(self):
# - By using self variable inside method we can able to access instance variables.
# - Within the class we can call instance method by using self variable and from outside of the class we can call by using object reference.

# %%
class Student:
    def __init__(self,x,y):
        self.name=x
        self.marks=y
        
    def display(self):
        print("HI",self.name)
        print("your marks are:",self.marks)
        
    def grade(self):
        if self.marks>=60:
            print("you got first grade")
        elif self.marks>=50:
            print("you got second grade")
        elif self.marks>=35:
            print("you got third grade")
        else:
            print("you are failed")
    
n=int(input("enter no. of Students::"))
for i in range(n):
    x=input("Enter name:")
    y=int(input("enter marks:"))
    s=Student(x,y)
    s.display()
    s.grade()
# Out:
# enter no. of Students::2
# Enter name:swamy
# enter marks:99
# HI swamy
# your marks are: 99
# you got first grade
# Enter name:pawan
# enter marks:88
# HI pawan
# your marks are: 88
# you got first grade

# %% [markdown]
# ## Getter(accessor) and Setter(mutator) methods
# - We can set and get the values of instance variables by using getter and setter methods.

# %%
class Student:
    def setName(self,name):
        self.name=name
        
    def setMarks(self,marks):
        self.marks=marks
        
    def getName(self):
        return self.name
    
    def getMarks(self):
        return self.marks
    
n=int(input("Enter no. of Students::"))
for i in range(n):
    s=Student()
    name=input("enter name:")
    s.setName(name)
    
    marks=int(input("enter marks:"))
    s.setMarks(marks)
    
    print("hi",s.getName())
    print("your marks are:",s.getMarks())
# Out:
# Enter no. of Students::2
# enter name:pawan
# enter marks:45
# hi pawan
# your marks are: 45
# enter name:kumar
# enter marks:65
# hi kumar
# your marks are: 65

# %% [markdown]
# ## class methods
# - Inside method implementation if we are using only class variables (static variables), then such type of methods we should declare as class method.
# - We can declare class method explicitly by using @classmethod decorator. For class method we should provide cls variable at the time of declaration
# - We can call classmethod by using classname or object reference variable.

# %% [markdown]
# ### Accessing class methods

# %%
class Car:
    wheel=4
    
    @classmethod
    def drive(cls,name):
        print("{} is {} wheel drive car".format(name,cls.wheel))
        
Car.drive("jeep")
Car.drive("fortuner")
# Out:
# jeep is 4 wheel drive car
# fortuner is 4 wheel drive car

# %% [markdown]
# ### Tracking no. of objects created for a class

# %%
class Test:
    count=0  #class variable
    def __init__(self):
        Test.count=Test.count+1
    
    @classmethod
    def noofobjects(cls):
        print("no. of objects created:",cls.count)

t1=Test()
t2=Test()
Test.noofobjects()

t3=Test()
t4=Test()
Test.noofobjects()
# Out:
# no. of objects created: 2
# no. of objects created: 4

# %% [markdown]
# ## Static methods
# - In general these methods are general utility methods.
# - Inside these methods we won't use any instance or class variables.
# - Here - we won't provide self or cls arguments at the time of declaration.
# - We can declare static method explicitly by using @staticmethod decorator We can access static methods by using classname or object reference

# %% [markdown]
# ### Accessing Static methods

# %%
class maths:
    @staticmethod
    def add(a,b):
        print("Sum:",a+b)
    @staticmethod    
    def sub(a,b):
        print("sub:",a-b)
    @staticmethod   
    def mul(a,b):
        print("Mul:",a*b)
        
maths.add(20,10)
maths.sub(20,10)
maths.mul(20,10)
# Out:
# Sum: 30
# sub: 10
# Mul: 200

# %% [markdown]
# #### Note: In general we can use only instance and static methods.Inside static method we can access class level variables by using class name.
# class methods are most rarely used methods in python.

# %% [markdown]
# #### whats happen when we are not passing the decorator?
# - def m1(cls):print("some method")
# - the type of method depends upon our way of calling
# - Test.m1() --> static method
# - t.m1()    --> Instance method

# %%
class Test:
    def m1(cls):
        print("some method: instance|static|class method")
        
    #above method is may be instance method or static method it is not class method because for class method decorator is must
    #so which method it is? it depends upon calling
    
#Test.m1(10)    #static method
t = Test()      #instance method
t.m1()
# Out:
# some method: instance|static|class method

# %% [markdown]
# ## Passing members of one class to another class
# - We can access members of one class inside another class.

# %%
class Employee:
    def __init__(self,eno,ename,esal):
        self.eno=eno
        self.ename=ename
        self.esal=esal
        
    def display(self):
        print("employee no:",self.eno)
        print("Employee name:",self.ename)
        print("Employee salary:",self.esal)
        
class Test:
    def modify(emp):                        #let me consider this method as instance and static, if it is instance, self(emp)
        emp.esal=emp.esal+1000              #self means current class(Test) object there is no esal variable in Test class
        emp.display()                       #so it is expecting emp object not self varibale finally it is static method
                                            # from Test class we are accessing the employee class functionality
e=Employee(10,"pawan",10000)
Test.modify(e)
# Out:
# employee no: 10
# Employee name: pawan
# Employee salary: 11000

# %%
import IPython.display as d
d.Image("E:/code/1.pythonofficial/img/mem1.png")

# %% [markdown]
# ## inner class
# - Sometimes we can declare a class inside another class,such type of classes are called inner classes.
# - Without existing one type of object if there is no chance of existing another type of object,then we should go for inner classes.
# - Example: Without existing Car object there is no chance of existing Engine object. Hence Engine class should be part of Car class.
# class Car: ..... class Engine:

# %% [markdown]
# #### Note: Without existing outer class object there is no chance of existing inner class object. Hence inner class object is always associated with outer class object.

# %%
class Outer:
    def __init__(self):
        print("Outer class Object")
        
    class Inner:
        def __init__(self):
            print("inner class object")
        
        def m1(self):
            print("inner class instance method")

# %%
o=Outer()
i = o.Inner()
i.m1()
# Out:
# Outer class Object
# inner class object
# inner class instance method

# %%
i=Outer().Inner()
i.m1()
# Out:
# Outer class Object
# inner class object
# inner class instance method

# %%
i=Outer().Inner().m1()
# Out:
# Outer class Object
# inner class object
# inner class instance method

# %%
class Person:
    def __init__(self):
        self.name='pawan'
        self.db=self.Dob()
        
    def display(self):
        print('Name:',self.name)
        
    class Dob:
        def __init__(self):
            self.dd=9
            self.mm=12
            self.yy=1994
        def display(self):
            print('Dob={}/{}/{}'.format(self.dd,self.mm,self.yy))
            
p=Person()
p.display()   # Name: pawan
x=p.db
x.display()   # Dob=9/12/1994
# Out:
# Name: pawan
# Dob=9/12/1994

# %%
class Human:
    
    def __init__(self):
        self.name = "pawan"
        self.head = self.Head()
        self.brain = self.head.Brain()
        
    def display(self):
        print("Hello",self.name)
        self.head.talk()
        self.brain.think()
        
    class Head:
        def talk(self):
            print("Talking..")
            
        class Brain:
            def think(self):
                print("Thinking..")
                
h = Human()
h.display()
# Out:
# Hello pawan
# Talking..
# Thinking..

# %%
class Human:
    
    def __init__(self):
        self.name = "pawan"
        self.head = self.Head()
        self.brain = self.Brain()
        
    def display(self):
        print("Hello",self.name)
        
    class Head:
        def talk(self):
            print("Talking..")
            
    class Brain:
        def think(self):
            print("Thinking..")
                
h = Human()
h.display()
h.head.talk()
h.brain.think()
# Out:
# Hello pawan
# Talking..
# Thinking..

# %% [markdown]
# ### Nested Methods: a method inside a method

# %%
class Test:
    def m1(self):
        def calc(a,b):                       # local method so we calling with in the method
            print("the sum:",a+b) 
            print("the sub:",a-b)
            print("the mul:",a*b)
            print("the div:",a/b)
            print()
            
        calc(10,20)
        calc(100,200)
        calc(1000,2000)
        
t = Test()
t.m1()
# Out:
# the sum: 30
# the sub: -10
# the mul: 200
# the div: 0.5
#
# the sum: 300
# the sub: -100
# the mul: 20000
# the div: 0.5
#
# the sum: 3000
# the sub: -1000
# the mul: 2000000
# the div: 0.5

# %% [markdown]
# ## Garbage collector
# - In old languages like C++, programmer is responsible for both creation and destruction of objects.Usually programmer taking very much care while creating object, but neglecting destruction of useless objects. Because of his neglectance, total memory can be filled with useless objects which creates memory problems and total application will be down with Out of memory error.
# - But in Python, We have some assistant which is always running in the background to destroy useless objects.Because this assistant the chance of failing Python program with memory problems is very less. This assistant is nothing but Garbage Collector.
# - Hence the main objective of Garbage Collector is to destroy useless objects.
# - If an object does not have any reference variable then that object eligible for Garbage Collection.

# %% [markdown]
# #### How to enable and disable Garbage Collector in our program:
# - By default Gargbage collector is enabled, but we can disable based on our requirement. In this context we can use the following functions of gc module.

# %%
import gc

print(gc.isenabled())

gc.disable()
print(gc.isenabled())

gc.enable()
print(gc.isenabled())
# Out:
# True
# False
# True

# %% [markdown]
# ## Destructor
# - Destructor is a special method and the name should be _ _ _del_ _ _ Just before destroying an object Garbage Collector always calls destructor to perform clean up activities (Resource deallocation activities like close database connection etc).
# - Once destructor execution completed then Garbage Collector automatically destroys that object.

# %% [markdown]
# #### Note: The job of destructor is not to destroy object and it is just to perform clean up activities.

# %%
import time
class Test:
    def __init__(self):
        print("Obj Inititalization...")
        
    def __del__(self):
        print("clean up activities...")
        
t1=Test()
t1=None
time.sleep(5)
print("the end..")
# Out:
# Obj Inititalization...
# clean up activities...
# the end..

# %% [markdown]
# #### Note: If the object does not contain any reference variable then only it is eligible fo GC. ie if the reference count is zero then only object eligible for GC

# %%
import time

class Test:
    def __init__(self):
        print("Constructor Execution...")
        
    def __del__(self):
        print("Destructor Execution...")

t1=Test()
t2=t1
t3=t2
print(id(t1))
print(id(t2))
print(id(t3))
# Out:
# Constructor Execution...
# 2116994835680
# 2116994835680
# 2116994835680

# %%
del t1
time.sleep(5)
print("object not yet destroyed after deleting t1")

del t2
time.sleep(5)
print("object not yet destroyed even after deleting t2")
print("I am trying to delete last reference variable...")

del t3
# Out:
# object not yet destroyed after deleting t1
# object not yet destroyed even after deleting t2
# I am trying to delete last reference variable...
# Destructor Execution...

# %%
import time

class Test:
    def __init__(self):
        print("Constructor Execution...")
    def __del__(self):
        print("Destructor Execution...")
        
list=[Test(),Test(),Test()]
del list
time.sleep(5)
print("End of application")
# Out:
# Constructor Execution...
# Constructor Execution...
# Constructor Execution...
# Destructor Execution...
# Destructor Execution...
# Destructor Execution...
# End of application

# %% [markdown]
# ### How to find the number of references of an object:
# - sys module contains getrefcount() function for this purpose.

# %%
import sys

class Test:
    pass

t1=Test()
t2=t1
t3=t1
t4=t1
print(sys.getrefcount(t1))
# Out:
# 5

# %% [markdown]
# #### Note: For every object, Python internally maintains one default reference variable self. so totally 5 references
